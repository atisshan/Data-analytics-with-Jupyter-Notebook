# %%
import pandas as pd

# %% [markdown]
# #### Reading an excel file

# %%
DataFrame = pd.read_excel("DataFiles/Bike_Sales_Prepare_Lab_3.4.7.xlsx")

# %% [markdown]
# #### For data inspection we use .head() , .tail() , .info() , .describe()

# %%
DataFrame.head()   # This returns the first 5 records
# Out:
#    Sales_Order #       Date  Day     Month  Year  Customer_Age  \
# 0         261695 2021-12-01  1.0  December  2021            39
# 1         261695 2021-12-01  1.0  December  2021            44
# 2         261697 2021-12-02  2.0  December  2021            37
# 3         261698 2021-12-02  2.0  December  2021            31
# 4         261699 2021-12-03  3.0  December  2021            37
#
#               Age_Group Customer_Gender         Country            State  \
# 0        Adults (35-64)               F   United States       California
# 1        Adults (35-64)               M  United Kingdom          England
# 2        Adults (35-64)               M   United States       California
# 3  Young Adults (25-34)               F       Australia  New South Wales
# 4        Adults (35-64)               F  United  States       California
#
#   Product_Category    Sub_Category        Product_Description  Order_Quantity  \
# ...

# %%
DataFrame.tail() #Returns the last 5 records
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender        Country             State  \
# 84        Adults (35-64)               M        Germany            Hessen
# 85  Young Adults (25-34)               F  United States            Oregon
# 86  Young Adults (25-34)               F         Canada  British Columbia
# 87        Adults (35-64)               F  United States        California
# 88        Adults (35-64)               M      Australia        Queensland
#
#    Product_Category    Sub_Category      Product_Description  Order_Quantity  \
# ...

# %%
DataFrame.tail(20) #Return the last 20 records
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 69         261763 2021-12-19  19.0  December  2021            18
# 70         261764 2021-12-19  19.0  December  2021            56
# 71         261765 2021-12-19  19.0  December  2021            39
# 72         261766 2021-12-20  20.0  December  2021            33
# 73         261767 2021-12-20  20.0  December  2021            57
# 74         261768 2021-12-20  20.0  December  2021            29
# 75         261769 2021-12-20  20.0  December  2021            35
# 76         261770 2021-12-20  20.0  December  2021            35
# 77         261771 2021-12-21  21.0  December  2021            26
# 78         261772 2021-12-21  21.0  December  2021            23
# 79         261773 2021-12-22  22.0  December  2021            30
# 80         261774 2021-12-22  22.0  December  2021            41
# 81         261775 2021-12-22  22.0  December  2021            19
# ...

# %%
DataFrame.head(100) #Return the first 100 records
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
DataFrame.info() #Summary of your dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sales_Order #        89 non-null     int64
#  1   Date                 89 non-null     datetime64[ns]
#  2   Day                  88 non-null     float64
#  3   Month                89 non-null     object
#  4   Year                 89 non-null     int64
#  5   Customer_Age         89 non-null     int64
#  6   Age_Group            88 non-null     object
#  7   Customer_Gender      89 non-null     object
#  8   Country              89 non-null     object
#  9   State                89 non-null     object
#  10  Product_Category     89 non-null     object
#  11  Sub_Category         89 non-null     object
#  12  Product_Description  88 non-null     object
#  13  Order_Quantity       88 non-null     float64
#  14   Unit_Cost           89 non-null     int64
# ...

# %%
DataFrame.describe() #Returns statistical summary of our data(for numerical columns)
# Out:
#        Sales_Order #                           Date        Day    Year  \
# count      89.000000                             89  88.000000    89.0
# mean   261738.067416  2021-12-13 10:31:00.674157312  13.534091  2021.0
# min    261695.000000            2021-12-01 00:00:00   1.000000  2021.0
# 25%    261716.000000            2021-12-08 00:00:00   8.750000  2021.0
# 50%    261738.000000            2021-12-13 00:00:00  13.500000  2021.0
# 75%    261760.000000            2021-12-19 00:00:00  19.000000  2021.0
# max    261782.000000            2021-12-24 00:00:00  24.000000  2021.0
# std        25.729713                            NaN   6.391353     0.0
#
#        Customer_Age  Order_Quantity   Unit_Cost    Unit_Price       Profit   \
# count     89.000000       88.000000    89.000000     89.000000    89.000000
# mean      34.202247        2.125000  1052.247191   1940.943820  1848.887640
# min       17.000000        1.000000     0.000000      0.000000   245.000000
# ...

# %%
DataFrame.columns #Returns columns titles in Dataset
# Out:
# Index(['Sales_Order #', 'Date', 'Day', 'Month', 'Year', 'Customer_Age',
#        'Age_Group', 'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product_Description', 'Order_Quantity', ' Unit_Cost ',
#        ' Unit_Price ', ' Profit ', ' Cost ', 'Revenue'],
#       dtype='object')
